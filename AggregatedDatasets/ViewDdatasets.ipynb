# %%
#!pip install pyarrow

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pyarrow.orc as orc
import plotly.express as px

df = pd.read_orc("./OutcomesH.orc")
df
# Out:
#             agg_Date_H      trade_id        price   quantity          time
# 0  2023-04-01 00:00:00  4.977007e+09  1799.137049  32.959638  1.680307e+12  \
# 1  2023-04-01 01:00:00  4.987584e+09  1800.295007  33.204249  1.680311e+12
# 2  2023-04-01 02:00:00  4.998817e+09  1799.564369  33.083271  1.680314e+12
# 3  2023-04-01 03:00:00  5.014096e+09  1799.700707  32.954299  1.680318e+12
# 4  2023-04-01 04:00:00  5.016301e+09  1799.965051  32.919944  1.680322e+12
# 5  2023-04-01 05:00:00  4.973597e+09  1800.094520  33.409023  1.680325e+12
# 6  2023-04-01 06:00:00  5.025134e+09  1799.941197  33.270946  1.680329e+12
# 7  2023-04-01 07:00:00  5.019941e+09  1799.841438  33.358020  1.680332e+12
# 8  2023-04-01 08:00:00  4.990974e+09  1800.421030  33.266804  1.680336e+12
# 9  2023-04-01 09:00:00  5.005212e+09  1800.486905  32.820220  1.680340e+12
# 10 2023-04-01 10:00:00  4.984839e+09  1800.438854  32.625512  1.680343e+12
# ...

# %%
df2 = pd.read_orc("./OutcomesT.orc")
df2

# %%
df3 = pd.read_orc("./TradesH.orc")
df3

# %%
df4 = pd.read_orc("./TradesT.orc")
df4

# %%
df5 = pd.read_orc("./TopChains.orc")
df5

# %%
df6 = pd.read_orc("./Data.orc")
df6
# Out:
#     lastOutcome  longestSellChainLength  firstPricelongestSellChain
# 0 -5.480622e+07                      18                 1749.124271  \
# 1 -1.396599e+07                      22                 1728.482461
#
#    lastPricelongestSellChain                          Date
# 0                1821.411581 2023-04-01 08:49:15.864999936
# 1                1756.818479 2023-04-02 08:26:47.035000064

# %% [markdown]
# ### Tipos de columas

# %%
df.dtypes

# %% [markdown]
# ### Dataframe Memory Usage

# %%
# Get memory usage of the DataFrame
memory_usage = df.memory_usage(deep=True).sum()

# Print the memory usage
print("Memory usage:", memory_usage, "bytes")
print("Memory usage:", memory_usage/1_000_000, "Mbytes")
